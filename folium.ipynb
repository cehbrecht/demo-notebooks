# %%
import folium

# %%
map = folium.Map(location=[44, -73], zoom_start=3)
wms_url = 'http://gis.srh.noaa.gov/arcgis/services/NDFDTemps/'
wms_url += 'MapServer/WMSServer'
wms_name = "Temperature"
wms_layers = 16
wms_format = "image/png"
map.add_wms_layer(wms_name=wms_name,
                   wms_url=wms_url,
                   wms_format=wms_format,
                   wms_layers=wms_layers,
                   wms_transparent=True)

map
# Out:
# /home/pingu/.conda/envs/demo/lib/python2.7/site-packages/ipykernel/__main__.py:11: FutureWarning: Map.add_wms_layer is deprecated. Use Map.add_children(WmsTileLayer(...)) instead
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>
